# %%
import pandas as pd 
import numpy as np

# %%
#Load the teams.csv dataset into a Pandas DataFrame.
df = pd.read_csv('teams.csv')

# %%
df
# Out:
#                       team group confederation host_nation world_cup_debut  \
# 0                   Mexico     A      CONCACAF         Yes              No
# 1              South Korea     A           AFC          No              No
# 2                  Czechia     A          UEFA          No              No
# 3             South Africa     A           CAF          No              No
# 4                   Canada     B      CONCACAF         Yes              No
# 5              Switzerland     B          UEFA          No              No
# 6   Bosnia and Herzegovina     B          UEFA          No              No
# 7                    Qatar     B           AFC          No              No
# 8                   Brazil     C      CONMEBOL          No              No
# 9                  Morocco     C           CAF          No              No
# 10                   Haiti     C      CONCACAF          No              No
# ...

# %%
#Display the first 10 rows of the dataset.
df.head(10)
# Out:
#                      team group confederation host_nation world_cup_debut  \
# 0                  Mexico     A      CONCACAF         Yes              No
# 1             South Korea     A           AFC          No              No
# 2                 Czechia     A          UEFA          No              No
# 3            South Africa     A           CAF          No              No
# 4                  Canada     B      CONCACAF         Yes              No
# 5             Switzerland     B          UEFA          No              No
# 6  Bosnia and Herzegovina     B          UEFA          No              No
# 7                   Qatar     B           AFC          No              No
# 8                  Brazil     C      CONMEBOL          No              No
# 9                 Morocco     C           CAF          No              No
#
#   eliminated_round
# 0              NaN
# 1      Group Stage
# 2      Group Stage
# 3      Group Stage
# 4      Round of 16
# 5              NaN
# ...

# %%
#Display the last 5 rows of the dataset.
df.tail()
# Out:
#           team group confederation host_nation world_cup_debut  \
# 43  Uzbekistan     K           AFC          No             Yes
# 44     England     L          UEFA          No              No
# 45       Ghana     L           CAF          No              No
# 46      Panama     L      CONCACAF          No              No
# 47     Croatia     L          UEFA          No              No
#
#    eliminated_round
# 43      Group Stage
# 44              NaN
# 45      Round of 32
# 46      Group Stage
# 47      Round of 32

# %%
#Find the total number of rows and columns in the dataset.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   team              48 non-null     object
#  1   group             48 non-null     object
#  2   confederation     48 non-null     object
#  3   host_nation       48 non-null     object
#  4   world_cup_debut   48 non-null     object
#  5   eliminated_round  36 non-null     object
# dtypes: object(6)
# memory usage: 2.4+ KB

# %%
df.describe()
# Out:
#           team group confederation host_nation world_cup_debut  \
# count       48    48            48          48              48
# unique      48    12             6           2               2
# top     Mexico     A          UEFA          No              No
# freq         1     4            16          45              44
#
#        eliminated_round
# count                36
# unique                3
# top         Group Stage
# freq                 17

# %%
#Display the column names of the dataset
df.columns
# Out:
# Index(['team', 'group', 'confederation', 'host_nation', 'world_cup_debut',
#        'eliminated_round'],
#       dtype='object')

# %%
#Check the data type of each column.
df.dtypes
# Out:
# team                object
# group               object
# confederation       object
# host_nation         object
# world_cup_debut     object
# eliminated_round    object
# dtype: object

# %%
#Find the number of missing values in each column.
df.isna()
# Out:
#      team  group  confederation  host_nation  world_cup_debut  \
# 0   False  False          False        False            False
# 1   False  False          False        False            False
# 2   False  False          False        False            False
# 3   False  False          False        False            False
# 4   False  False          False        False            False
# 5   False  False          False        False            False
# 6   False  False          False        False            False
# 7   False  False          False        False            False
# 8   False  False          False        False            False
# 9   False  False          False        False            False
# 10  False  False          False        False            False
# 11  False  False          False        False            False
# 12  False  False          False        False            False
# 13  False  False          False        False            False
# ...

# %%
df.isna().sum()
# Out:
# team                 0
# group                0
# confederation        0
# host_nation          0
# world_cup_debut      0
# eliminated_round    12
# dtype: int64

# %%
#Display only the team and group columns.
df[['team','group']]
# Out:
#                       team group
# 0                   Mexico     A
# 1              South Korea     A
# 2                  Czechia     A
# 3             South Africa     A
# 4                   Canada     B
# 5              Switzerland     B
# 6   Bosnia and Herzegovina     B
# 7                    Qatar     B
# 8                   Brazil     C
# 9                  Morocco     C
# 10                   Haiti     C
# 11                Scotland     C
# 12           United States     D
# 13               Australia     D
# 14                 Turkiye     D
# 15                Paraguay     D
# 16                 Germany     E
# 17             Ivory Coast     E
# 18                 Ecuador     E
# 19                 Curacao     E
# 20                  Sweden     F
# 21             Netherlands     F
# 22                   Japan     F
# 23                 Tunisia     F
# 24                 Belgium     G
# 25                   Egypt     G
# 26                    Iran     G
# ...

# %%
#Find the number of unique confederations.
df['confederation'].unique()
# Out:
# array(['CONCACAF', 'AFC', 'UEFA', 'CAF', 'CONMEBOL', 'OFC'], dtype=object)

# %%
#Display all unique values in the eliminated_round column
df['eliminated_round'].unique()
# Out:
# array([nan, 'Group Stage', 'Round of 16', 'Round of 32'], dtype=object)

# %%
#Display all teams belonging to Group A
df[df['group'] == 'A']
# Out:
#            team group confederation host_nation world_cup_debut  \
# 0        Mexico     A      CONCACAF         Yes              No
# 1   South Korea     A           AFC          No              No
# 2       Czechia     A          UEFA          No              No
# 3  South Africa     A           CAF          No              No
#
#   eliminated_round
# 0              NaN
# 1      Group Stage
# 2      Group Stage
# 3      Group Stage

# %%
#Find all teams whose confederation is UEFA.
df[df['confederation'] == 'UEFA']
# Out:
#                       team group confederation host_nation world_cup_debut  \
# 2                  Czechia     A          UEFA          No              No
# 5              Switzerland     B          UEFA          No              No
# 6   Bosnia and Herzegovina     B          UEFA          No              No
# 11                Scotland     C          UEFA          No              No
# 14                 Turkiye     D          UEFA          No              No
# 16                 Germany     E          UEFA          No              No
# 20                  Sweden     F          UEFA          No              No
# 21             Netherlands     F          UEFA          No              No
# 24                 Belgium     G          UEFA          No              No
# 28                   Spain     H          UEFA          No              No
# 32                  France     I          UEFA          No              No
# ...

# %%
#Display all host nations (host_nation == True)
df[df['host_nation'] == True]
# Out:
# Empty DataFrame
# Columns: [team, group, confederation, host_nation, world_cup_debut, eliminated_round]
# Index: []

# %%
#Find the number of teams in each group.
df.groupby('group').size().reset_index(name='team_count')
# Out:
#    group  team_count
# 0      A           4
# 1      B           4
# 2      C           4
# 3      D           4
# 4      E           4
# 5      F           4
# 6      G           4
# 7      H           4
# 8      I           4
# 9      J           4
# 10     K           4
# 11     L           4

# %%
#Count how many teams belong to each confederation
df.groupby('confederation')['team'].count()
# Out:
# confederation
# AFC          9
# CAF         10
# CONCACAF     6
# CONMEBOL     6
# OFC          1
# UEFA        16
# Name: team, dtype: int64

# %%
#Sort the dataset by world_cup_debut in ascending order.
df.sort_values(by='world_cup_debut', ascending=True)
df.sort_values(by='world_cup_debut', ascending=True)
# Out:
#                       team group confederation host_nation world_cup_debut  \
# 0                   Mexico     A      CONCACAF         Yes              No
# 24                 Belgium     G          UEFA          No              No
# 25                   Egypt     G           CAF          No              No
# 26                    Iran     G           AFC          No              No
# 27             New Zealand     G           OFC          No              No
# 28                   Spain     H          UEFA          No              No
# 30            Saudi Arabia     H           AFC          No              No
# 31                 Uruguay     H      CONMEBOL          No              No
# 32                  France     I          UEFA          No              No
# 33                  Norway     I          UEFA          No              No
# 34                 Senegal     I           CAF          No              No
# ...

# %%
#Count how many teams were eliminated in each round
df['eliminated_round'].count()
# Out:
# np.int64(36)

# %%
#Create a summary table showing the number of teams in each confederation and their eliminated rounds using groupby().
df.groupby(['confederation', 'eliminated_round']).size().reset_index(name='Number_of_Teams')
# Out:
#    confederation eliminated_round  Number_of_Teams
# 0            AFC      Group Stage                7
# 1            AFC      Round of 32                2
# 2            CAF      Group Stage                2
# 3            CAF      Round of 32                6
# 4       CONCACAF      Group Stage                3
# 5       CONCACAF      Round of 16                1
# 6       CONCACAF      Round of 32                1
# 7       CONMEBOL      Group Stage                1
# 8       CONMEBOL      Round of 16                2
# 9       CONMEBOL      Round of 32                1
# 10           OFC      Group Stage                1
# 11          UEFA      Group Stage                3
# 12          UEFA      Round of 32                6
